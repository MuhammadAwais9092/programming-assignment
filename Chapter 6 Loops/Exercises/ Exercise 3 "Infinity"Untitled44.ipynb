# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAwais9092/programming-assignment/blob/main/Chapter%206%20Loops/Exercises/%20Exercise%203%20%22Infinity%22Untitled44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Chapter 6 Exercise 3 "Infinity"

#Assigning value to variable count
count=666
while count<=666:        # Writing a loop that never ends
  print(count)
# Out:
# Streaming output truncated to the last 5000 lines.
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# 666
# ...
