# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAwais9092/programming-assignment/blob/main/Final%20Assignment/Practise/%20practise%202%20Untitled74.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project:  Vending Machine

# Creating a list of products inside the vending machines
# Including products code and prices
Stocked_items=[
    {
        "Item_code"  : 0,
        "Name_Item"  : "   Soda     ",
        "Item_Price" : 3.00,
     },

     {
         "Item_code"  : 1,
         "Name_Item"  : " Choco Bar  ",
         "Item_Price" : 2.00,
     },

     {
         "Item_code"  : 2,
         "Name_Item"  : "   Chips    ",
         "Item_Price" : 1.00,
     },

     {
         "Item_code"  : 3,
         "Name_Item"  : "   Coffee   ",
         "Item_Price" : 5.00,
     },

     {
         "Item_code"  : 4,
         "Name_Item"  : " Ice cream  ",
         "Item_Price" : 6.00,
     },

     {
         "Item_code"  : 5,
         "Name_Item"  : "Energy drink",
         "Item_Price" : 3.00,
     },
]

the_item = []

reciept = """
\t\tPRODUCT -- PRICE
"""

sum = 0

run = True

# Printing the list of products stocked inside vending machine

print(" The Products Inside Vending Machine Are : \n\n")

for i in Stocked_items:
    print(f"Item: {i['Name_Item']} ---------- Price: Aed {i['Item_Price']} ..... Items-Code: {i['Item_code']}")


def machine(Stocked_items, run, the_item):
    while run:

        buy_item = int(input("\n\n Enter the code of the product you want to buy: "))

        if buy_item < len(Stocked_items):
            the_item.append(Stocked_items[buy_item])
        else:
            print("THE PRODUCT CODE IS WRONG!")

        more_items = str(input("Press any key to add more items and press q to quit.. "))

        if more_items == "q":
            run = False

    rec_bool = int(input(("1. print the reciept? 2. only print the total sum .. ")))
    if rec_bool == 1:
        print(create_reciept(the_item, reciept))
    elif rec_bool == 2:
        print(sum(the_item))
    else:
        print("INVALID ENTRY")


def sum(the_item):
    sum = 0

    for i in the_item:
        sum += i["Item_Price"]

    return sum

def create_reciept(the_item, reciept):

    for i in the_item:
        reciept += f"""
        \t{i["Name_Item"]} -- {i['Item_Price']}
        """

    reciept += f"""
        \tTotal --- {sum(the_item)}
        
        
        """
    return reciept


if __name__ == "__main__":
    machine(Stocked_items, run, the_item)
# Out:
#  The Products Inside Vending Machine Are :
#
#
# Item:    Soda      ---------- Price: Aed 3.0 ..... Items-Code: 0
# Item:  Choco Bar   ---------- Price: Aed 2.0 ..... Items-Code: 1
# Item:    Chips     ---------- Price: Aed 1.0 ..... Items-Code: 2
# Item:    Coffee    ---------- Price: Aed 5.0 ..... Items-Code: 3
# Item:  Ice cream   ---------- Price: Aed 6.0 ..... Items-Code: 4
# Item: Energy drink ---------- Price: Aed 3.0 ..... Items-Code: 5
#
#
#  Enter the code of the product you want to buy: 1
# Press any key to add more items and press q to quit.. 2
#
#
#  Enter the code of the product you want to buy: 2
# Press any key to add more items and press q to quit.. 2
#
#
#  Enter the code of the product you want to buy: 5
# Press any key to add more items and press q to quit.. q
# 1. print the reciept? 2. only print the total sum .. 2
# 6.0
